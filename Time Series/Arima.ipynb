# %% [markdown]
# # Arima Model

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Obtaining dependency information for pmdarima from https://files.pythonhosted.org/packages/ac/f8/6c9364602b13f0dba129b53acd1344859690911a4d5021560d9fd6aa087f/pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/30/ca/d68432adc1bf90b450c4d9aaf7cbadae50bca0cad1686b1976498abe2eca/Cython-3.0.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cython-3.0.5-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (1.11.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (68.0.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\excel\anaconda3\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\excel\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\excel\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\excel\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\excel\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\excel\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\excel\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp311-cp311-win_amd64.whl (614 kB)
#    ---------------------------------------- 0.0/614.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/614.7 kB ? eta -:--:--
#    ----- ---------------------------------- 92.2/614.7 kB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 378.9/614.7 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  614.4/614.7 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 614.7/614.7 kB 3.8 MB/s eta 0:00:00
# Downloading Cython-3.0.5-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.4/2.8 MB 10.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.8 MB 7.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/2.8 MB 7.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 7.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.9/2.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------- -------- 2.2/2.8 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.5/2.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.5 pmdarima-2.0.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid')
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/AveargeTemp.csv', index_col=0, parse_dates=True)
df
# Out:
#             AvgTemp
# DATE
# 01-01-2014       40
# 02-01-2014       43
# 03-01-2014       41
# 04-01-2014       37
# 05-01-2014       31
# ...             ...
# 26-12-2018       40
# 27-12-2018       39
# 28-12-2018       40
# 29-12-2018       42
# 30-12-2018       46
#
# [1821 rows x 1 columns]

# %%
df['AvgTemp']
# Out:
# DATE
# 01-01-2014    40
# 02-01-2014    43
# 03-01-2014    41
# 04-01-2014    37
# 05-01-2014    31
#               ..
# 26-12-2018    40
# 27-12-2018    39
# 28-12-2018    40
# 29-12-2018    42
# 30-12-2018    46
# Name: AvgTemp, Length: 1821, dtype: int64

# %% [markdown]
# **Check stationarity of the data**

# %%
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# - We can see that it seems to have somewhat of a constant mean around 45. And the fluctuations also seem to be more or less the same. However to be sure if the data is stationary or not we will run adfuller test.

# %%
adfuller(df['AvgTemp'])[1]
# Out:
# 8.67593748019975e-09

# %% [markdown]
# **Null hypothesis: Data is Non stationary**
#
# **Alternate Hypothesis: Data is Stationary**
#
#
#
# - If p< 0.05 ; Data is stationary
#
# - if p>0.05; Data is not stationary
#
# **According the p-value, the dataset is stationary as the p value is less than alpha value.**

# %% [markdown]
# # Arima model building.
# - ARIMA is composed of 3 terms(Auto-Regression(p) + Integrated(d) + Moving-Average(q))
# - First, we need to find out the order of arima model.

# %%
#find out order of arima

# %%
order = auto_arima(df['AvgTemp'])

# %%
order
# Out:
# ARIMA(order=(1, 0, 5), scoring_args={}, suppress_warnings=True)

# %%
df.shape
# Out:
# (1821, 1)

# %%
#Split the data
train = df.iloc[:-30]
test = df.iloc[-30:]

# %%
train.shape
# Out:
# (1791, 1)

# %%
test.shape
# Out:
# (30, 1)

# %%
#Arima model

# %%
model = ARIMA(train['AvgTemp'], order=(1, 0, 5)).fit()

# %% [markdown]
# # Evaluating the model

# %%
test
# Out:
#             AvgTemp
# DATE
# 01-12-2018       44
# 02-12-2018       42
# 03-12-2018       45
# 04-12-2018       48
# 05-12-2018       45
# 06-12-2018       44
# 07-12-2018       45
# 08-12-2018       44
# 09-12-2018       45
# 10-12-2018       46
# 11-12-2018       47
# 12-12-2018       47
# 13-12-2018       45
# 14-12-2018       46
# 15-12-2018       47
# 16-12-2018       49
# 17-12-2018       51
# 18-12-2018       43
# 19-12-2018       42
# 20-12-2018       48
# 21-12-2018       50
# 22-12-2018       47
# 23-12-2018       47
# 24-12-2018       44
# 25-12-2018       42
# 26-12-2018       40
# 27-12-2018       39
# 28-12-2018       40
# 29-12-2018       42
# 30-12-2018       46

# %%
ypred = model.predict(start =1791, end = 1820)
ypred
# Out:
# 1791    44.754109
# 1792    44.987795
# 1793    45.388741
# 1794    45.721546
# 1795    45.863733
# 1796    45.874126
# 1797    45.884370
# 1798    45.894466
# 1799    45.904417
# 1800    45.914225
# 1801    45.923891
# 1802    45.933419
# 1803    45.942809
# 1804    45.952064
# 1805    45.961185
# 1806    45.970176
# 1807    45.979036
# 1808    45.987770
# 1809    45.996377
# 1810    46.004861
# 1811    46.013222
# 1812    46.021463
# 1813    46.029586
# 1814    46.037591
# 1815    46.045482
# 1816    46.053258
# 1817    46.060923
# 1818    46.068477
# 1819    46.075923
# 1820    46.083261
# Name: predicted_mean, dtype: float64

# %%
print(np.sqrt(mean_squared_error(test['AvgTemp'], ypred)))
# Out:
# 3.0004639077669406
