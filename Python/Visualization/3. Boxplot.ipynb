# %% [markdown]
# # BOXPLOT
#
# -  A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.

# %% [markdown]
# ![BOXPLOT.png](attachment:BOXPLOT.png)

# %% [markdown]
# **COMPARISON BETWEEN BOXPLOT AND NORMAL DISTRIBUTION PLOT**
#
# ![Box-distribution.png](attachment:Box-distribution.png)

# %%
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pe
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 200
sns.set_theme(style='darkgrid')

# %%
#Cars dataset

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
plt.boxplot(df['width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27d30afdd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27d30b01400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27d30afda00>],
#  'medians': [<matplotlib.lines.Line2D at 0x27d30b01be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27d30b01e80>],
#  'means': []}

# %%
plt.boxplot(df['width'], vert=False, notch = True, showmeans = True,patch_artist=True)
plt.show()

# %%
#For entire dataset

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Seaborn Boxplot

# %%
sns.boxplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.boxplot(x = df['price'],y = df['make'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='make'>

# %%
df[df['make'] == 'renault']
# Out:
#      symboling normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0                 ?  renault       gas      wagon          fwd
# 131          2                 ?  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 130           front   66.5    55.2         ohc          132          ?
# 131           front   66.6    50.5         ohc          132          ?
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895

# %% [markdown]
# # Plotly Boxplot

# %%
pe.box(df['height'], orientation='h')
# Out:
# <div>                            <div id="5f8df5a3-a152-47fb-8541-36e9de0eb419" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8df5a3-a152-47fb-8541-36e9de0eb419")) {                    Plotly.newPlot(                        "5f8df5a3-a152-47fb-8541-36e9de0eb419",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}<br>variable=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[48.8,48.8,52.4,54.3,54.3,53.1,55.7,55.7,55.9,52.0,54.3,54.3,54.3,54.3,55.7,55.7,53.7,56.3,53.2,52.0,52.0,50.8,50.8,50.8,50.6,50.6,50.6,50.6,59.8,50.2,50.8,50.8,52.6,52.6,52.6,54.5,58.3,53.3,53.3,54.1,54.1,54.1,51.0,53.5,52.0,52.0,51.4,52.8,52.8,47.8,
# ...

# %% [markdown]
# # Subplots

# %%
#Subplot

plt.subplot(2,2,1)
sns.countplot(df['body-style'])

plt.subplot(2,2,2)
sns.scatterplot(df['engine-size'], df['price'])

plt.subplot(2,2,3)
sns.boxplot(df['engine-size'])

plt.subplot(2,2,4)
sns.histplot(df['width'])

plt.tight_layout()

# %%
#Subplots

# %%
fig,index = plt.subplots(2,2)

sns.scatterplot(df['engine-size'],df['price'], ax =  index[0,0])
sns.countplot(df['fuel-type'], ax=index[1,1])
sns.kdeplot(df['price'],ax = index[0,1])
sns.distplot(df['engine-size'],ax = index[1,0])

plt.tight_layout()
