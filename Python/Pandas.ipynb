# %% [markdown]
# # Pandas
#
# - Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
# - It provides various data structures and operations for manipulating numerical data and time series.
# - This library is built on top of the NumPy library.
# - Pandas is fast and it has high performance & productivity for users.
# - Pandas generally provide two data structures for manipulating data, They are:
#    - Series
#    - DataFrame

# %%
#Importing necessary libraries

# %%
import pandas as pd

# %%
pandas.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # DataFrame
# - A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns

# %%
df = pd.DataFrame({
    'Name':['Abhisha','Nikita','Aryan'],
    'Age' : [22,23,25],
    'Subject Name' : ['ML','Python','DL'],
    'City' : ['Pune','Mumbai','Chennai']
})

# %%
df
# Out:
#       Name  Age Subject Name     City
# 0  Abhisha   22           ML     Pune
# 1   Nikita   23       Python   Mumbai
# 2    Aryan   25           DL  Chennai

# %%
#Check number of rows and columns in dataframe

# %%
df.shape
# Out:
# (3, 4)

# %%
#Dimesion of the dataframe

# %%
df.ndim
# Out:
# 2

# %%
#Data type of each column

# %%
df.dtypes
# Out:
# Name            object
# Age              int64
# Subject Name    object
# City            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          3 non-null      object
#  1   Age           3 non-null      int64
#  2   Subject Name  3 non-null      object
#  3   City          3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   23.333333
# std     1.527525
# min    22.000000
# 25%    22.500000
# 50%    23.000000
# 75%    24.000000
# max    25.000000

# %%
df.describe(include=object)
# Out:
#            Name Subject Name  City
# count         3            3     3
# unique        3            3     3
# top     Abhisha           ML  Pune
# freq          1            1     1

# %%
#Extracting columns from dataframe

# %%
df
# Out:
#       Name  Age Subject Name     City
# 0  Abhisha   22           ML     Pune
# 1   Nikita   23       Python   Mumbai
# 2    Aryan   25           DL  Chennai

# %%
df['Name']
# Out:
# 0    Abhisha
# 1     Nikita
# 2      Aryan
# Name: Name, dtype: object

# %%
df.Name
# Out:
# 0    Abhisha
# 1     Nikita
# 2      Aryan
# Name: Name, dtype: object

# %%
df.Subject Name
# Out:
#   File "C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_4572\2012363542.py", line 1
#     df.Subject Name
#                ^
# SyntaxError: invalid syntax

# %%
df['Subject Name']
# Out:
# 0        ML
# 1    Python
# 2        DL
# Name: Subject Name, dtype: object

# %% [markdown]
# # Importing External Dataset

# %%
#Load the csv file
pd.read_csv(r"C:\Users\Aishwarya\Desktop\Datasets\Churn_Modelling.csv")
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# 2                  0        113931.57       1
# 3                  0         93826.63       0
# 4                  1         79084.10       0
# ...              ...              ...     ...
# 9995               0         96270.64       0
# 9996               1        101699.77       0
# 9997               1         42085.58       1
# 9998               0         92888.52       1
# 9999               0         38190.78       0
#
# [10000 rows x 9 columns]

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#Reading first 5 records

# %%
df.head(10)
# Out:
#         rank discipline  phd  service gender  salary
# 0       Prof          B   56       49   Male  186960
# 1       Prof          A   12        6   Male   93000
# 2       Prof          A   23       20   Male  110515
# 3       Prof          A   40       31   Male  131205
# 4       Prof          B   20       18   Male  104800
# 5       Prof          A   20       20   Male  122400
# 6  AssocProf          A   20       17   Male   81285
# 7       Prof          A   18       18   Male  126300
# 8       Prof          A   29       19   Male   94350
# 9       Prof          A   51       51   Male   57800

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 28   AsstProf          B    7        2    Male   91300
# 29       Prof          B   21       20    Male  123683
# 30  AssocProf          B    9        7    Male  107008
# 31       Prof          B   22       21    Male  155750
# 32       Prof          A   27       19    Male  103275
# 33       Prof          B   18       18    Male  120000
# 34  AssocProf          B   12        8    Male  119800
# 35       Prof          B   28       23    Male  126933
# 36       Prof          B   45       45    Male  146856
# 37       Prof          A   20        8    Male  102000
# 38   AsstProf          B    4        3    Male   91000
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# 55   AsstProf          A    2        0  Female   72500
# 56  AssocProf          A   10        8  Female   77500
# 57   AsstProf          A    3        1  Female   72500
# 58       Prof          B   36       26  Female  144651
# 59  AssocProf          B   12       10  Female  103994
# 60   AsstProf          B    3        3  Female   92000
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#Descriptive stats
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df.skew()
# Out:
# C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_4572\1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# phd        0.634366
# service    0.913750
# salary     0.452103
# dtype: float64

# %%
#Selecting single and multiple columns

# %%
df[['phd','service','salary']]
# Out:
#     phd  service  salary
# 0    56       49  186960
# 1    12        6   93000
# 2    23       20  110515
# 3    40       31  131205
# 4    20       18  104800
# 5    20       20  122400
# 6    20       17   81285
# 7    18       18  126300
# 8    29       19   94350
# 9    51       51   57800
# 10   39       33  128250
# 11   23       23  134778
# 12    1        0   88000
# 13   35       33  162200
# 14   25       19  153750
# 15   17        3  150480
# 16    8        3   75044
# 17    4        0   92000
# 18   19        7  107300
# 19   29       27  150500
# 20    4        4   92000
# 21   33       30  103106
# 22    4        2   73000
# 23    2        0   85000
# 24   30       23   91100
# 25   35       31   99418
# 26   38       19  148750
# 27   45       43  155865
# 28    7        2   91300
# 29   21       20  123683
# 30    9        7  107008
# 31   22       21  155750
# 32   27       19  103275
# 33   18       18  120000
# 34   12        8  119800
# 35   28       23  126933
# 36   45       45  146856
# 37   20        8  102000
# 38    4        3   91000
# 39   18       18  129000
# 40   39       36  137000
# 41   13        8   74830
# 42    4        2   80225
# 43    5        0   77000
# 44   23       19  151768
# 45   25       25  140096
# 46   11        3   74692
# 47   11       11  103613
# 48   17       17  111512
# 49   17       18  122960
# 50   10        5   97032
# 51   20       14  127512
# 52   12        0  105000
# 53    5        3   73500
# 54   25       22   62884
# 55    2        0   72500
# 56   10        8   77500
# 57    3        1   72500
# 58   36       26  144651
# 59   12       10  103994
# 60    3        3   92000
# 61   13       10  103750
# 62   14        7  109650
# 63   29       27   91000
# 64   26       24   73300
# 65   36       19  117555
# 66    7        6   63100
# 67   17       11   90450
# 68    4        2   77500
# 69   28        7  116450
# 70    8        3   78500
# 71   12        9   71065
# 72   24       15  161101
# 73   18       10  105450
# 74   19        6  104542
# 75   17       17  124312
# 76   28       14  109954
# 77   23       15  109646

# %%
#Selecting columns with loc and iloc
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
#loc function

# %%
df.loc[5:30,'rank':'phd']
# Out:
#          rank discipline  phd
# 5        Prof          A   20
# 6   AssocProf          A   20
# 7        Prof          A   18
# 8        Prof          A   29
# 9        Prof          A   51
# 10       Prof          B   39
# 11       Prof          B   23
# 12   AsstProf          B    1
# 13       Prof          B   35
# 14       Prof          B   25
# 15       Prof          B   17
# 16   AsstProf          B    8
# 17   AsstProf          B    4
# 18       Prof          A   19
# 19       Prof          A   29
# 20   AsstProf          B    4
# 21       Prof          A   33
# 22   AsstProf          A    4
# 23   AsstProf          A    2
# 24       Prof          A   30
# 25       Prof          B   35
# 26       Prof          A   38
# 27       Prof          A   45
# 28   AsstProf          B    7
# 29       Prof          B   21
# 30  AssocProf          B    9

# %%
df.iloc[5:31,0:3]
# Out:
#          rank discipline  phd
# 5        Prof          A   20
# 6   AssocProf          A   20
# 7        Prof          A   18
# 8        Prof          A   29
# 9        Prof          A   51
# 10       Prof          B   39
# 11       Prof          B   23
# 12   AsstProf          B    1
# 13       Prof          B   35
# 14       Prof          B   25
# 15       Prof          B   17
# 16   AsstProf          B    8
# 17   AsstProf          B    4
# 18       Prof          A   19
# 19       Prof          A   29
# 20   AsstProf          B    4
# 21       Prof          A   33
# 22   AsstProf          A    4
# 23   AsstProf          A    2
# 24       Prof          A   30
# 25       Prof          B   35
# 26       Prof          A   38
# 27       Prof          A   45
# 28   AsstProf          B    7
# 29       Prof          B   21
# 30  AssocProf          B    9

# %%
#Number of unique values
df['rank'].nunique()
# Out:
# 3

# %%
#Unique values in a column

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
#Value counts

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
#Renaming column names

# %%
df.rename(columns={'rank':'RANK'},inplace=True)

# %%
df
# Out:
#          RANK discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 28   AsstProf          B    7        2    Male   91300
# 29       Prof          B   21       20    Male  123683
# 30  AssocProf          B    9        7    Male  107008
# 31       Prof          B   22       21    Male  155750
# 32       Prof          A   27       19    Male  103275
# 33       Prof          B   18       18    Male  120000
# 34  AssocProf          B   12        8    Male  119800
# 35       Prof          B   28       23    Male  126933
# 36       Prof          B   45       45    Male  146856
# 37       Prof          A   20        8    Male  102000
# 38   AsstProf          B    4        3    Male   91000
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# 55   AsstProf          A    2        0  Female   72500
# 56  AssocProf          A   10        8  Female   77500
# 57   AsstProf          A    3        1  Female   72500
# 58       Prof          B   36       26  Female  144651
# 59  AssocProf          B   12       10  Female  103994
# 60   AsstProf          B    3        3  Female   92000
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.rename(columns={'phd':'PHD','gender':'GENDER'},inplace=True)

# %%
df
# Out:
#          RANK discipline  PHD  service  GENDER  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 28   AsstProf          B    7        2    Male   91300
# 29       Prof          B   21       20    Male  123683
# 30  AssocProf          B    9        7    Male  107008
# 31       Prof          B   22       21    Male  155750
# 32       Prof          A   27       19    Male  103275
# 33       Prof          B   18       18    Male  120000
# 34  AssocProf          B   12        8    Male  119800
# 35       Prof          B   28       23    Male  126933
# 36       Prof          B   45       45    Male  146856
# 37       Prof          A   20        8    Male  102000
# 38   AsstProf          B    4        3    Male   91000
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# 55   AsstProf          A    2        0  Female   72500
# 56  AssocProf          A   10        8  Female   77500
# 57   AsstProf          A    3        1  Female   72500
# 58       Prof          B   36       26  Female  144651
# 59  AssocProf          B   12       10  Female  103994
# 60   AsstProf          B    3        3  Female   92000
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
